# %%
import requests

headers = {
    'Content-Type': 'application/json'
}
URL="https://api.tiingo.com/tiingo/daily/NKE/prices?startDate=2012-1-1&endDate=2016-1-1&token=19e59db3a5d748a1d7528c0a6aa46736f38e9277"
response=requests.get(url=URL, headers=headers)
response.json()
# Out:
# [{'date': '2012-01-03T00:00:00.000Z',
#   'close': 96.81,
#   'high': 97.99,
#   'low': 96.7,
#   'open': 97.37,
#   'volume': 2736100,
#   'adjClose': 21.523201523,
#   'adjHigh': 21.7855440269,
#   'adjLow': 21.4987458659,
#   'adjOpen': 21.6477030503,
#   'adjVolume': 10944400,
#   'divCash': 0.0,
#   'splitFactor': 1.0},
#  {'date': '2012-01-04T00:00:00.000Z',
#   'close': 98.22,
#   'high': 98.755,
#   'low': 96.51,
#   'open': 96.71,
#   'volume': 2360200,
#   'adjClose': 21.8366785827,
#   'adjHigh': 21.955622006,
#   'adjLow': 21.4565042763,
#   'adjOpen': 21.5009691074,
#   'adjVolume': 9440800,
#   'divCash': 0.0,
#   'splitFactor': 1.0},
#  {'date': '2012-01-05T00:00:00.000Z',
#   'close': 98.16,
#   'high': 98.58,
#   'low': 97.0,
#   'open': 97.79,
#   'volume': 2098300,
#   'adjClose': 21.8233391333,
#   'adjHigh': 21.9167152788,
#   'adjLow': 21.5654431126,
#   'adjOpen': 21.7410791957,
#   'adjVolume': 8393200,
#   'divCash': 0.0,
#   'splitFactor': 1.0},
# ...
